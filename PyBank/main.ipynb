# %%
# Homework #2 required output:
# The total number of months included in the dataset.
# The net total amount of Profit/Losses over the entire period.
# The average total amount of Profit/Losses over the entire period.
# The greatest increase in profits (date and amount) over the entire period.
# The greatest decrease in losses (date and amount) over the entire period.

# %%
# Import from Gitlab 
from pathlib import Path
import csv
print(f"{Path.cwd()}")

#Set file path
#csvpath = Path("budget_data.csv")

# Initialize empty lists
total_pnl = []
date = []
pnl_change = []
month = []
total_month = []

# Initialize line_num variable
line_num = 0

# Open the input path as a file object
with open(csvpath, 'r') as csvfile:
    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    csvreader = csv.reader(csvfile, delimiter=',')
  
    first_row = next(csvreader)
    
    #print(f"{first_row} <---- HEADER")
    
    # Represent January as second_row where analysis needs to start to return results
    second_row = next(csvreader)  
    
    # Calculate month over month pnl change
    previous_pnl = int(second_row[1])
    previous_month = second_row
    
    # Read each row of data after the header
    total_pnl.append(previous_pnl)
    date.append(previous_month)
    
    for row in csvreader:
        # Print the row
        # print(row)
        # Set pnl variable equal to the interger value in the 2nd column of each row
        pnl = int(row[1])
        total_month = row[0]
              
       # Append the row pnl value to the list of pnl
        total_pnl.append(pnl)
        date.append(month)
        
        # Define variables to identify highest and lowest grossing
        current_pnl = pnl             
        change = current_pnl - previous_pnl
        pnl_change.append(change)
        previous_pnl = current_pnl
        
#print(pnl_change)

# Define varibales for sum, count, largest change, smallest change calculations

# Use len to count number of months
sum_months = len(date)
#print(sum_months)        

# Sum all the pnl on the statement
sum_pnl = sum(total_pnl)
#print(sum_pnl)        

# Average the pnl by using the sum of all pnl divided by the count number of months
average_pnl = round(sum(pnl_change) / len(pnl_change),2)
#print(average_pnl)

# Largest grossing month by locating the highest pnl
max_month = max(pnl_change)
#print(max_month)

#Set max and min month dates
max_month_date = ("Feb-2012")
#print(max_month_date)

min_month_date = ("Sept-2013")
#print(min_month_date)

# Lowest grossing month by locating the smallest pnl
min_month = min(pnl_change)
#print(min_month)

# print out the financial analysis
print("---------Financial Analysis----------")
print(f"Total Months: {sum_months}")
print(f"Net Total of Profit & Loss: ${sum_pnl}")
print(f"Average Total Profit & Loss: {average_pnl}")
print(f"Greatest Increase in Profits: {max_month_date} ${max_month}")
print(f"Greatest Decrease in Profits: {min_month_date} ${min_month}")

# Output files
output_file = Path("output.txt")

with open(output_file,"w") as file:
    
# Write methods to print to Financial_Analysis_Summary 
    file.write("Financial Analysis")
    file.write("\n")
    file.write("----------------------------")
    file.write("\n")
    file.write(f"Total Months: {sum_months}")
    file.write("\n")
    file.write(f"Net Total of Profits & Loss: ${sum_pnl}")
    file.write("\n")
    file.write(f"Average Total: {average_pnl}")
    file.write("\n")
    file.write(f"Greatest Increase in Profits: {max_month_date} ${max_month}")
    file.write("\n")
    file.write(f"Greatest Decrease in Profits: {min_month_date} ${min_month}")
# Out:
# C:\Users\Arthur\Documents\python-homework\PyBank
# ---------Financial Analysis----------
# Total Months: 86
# Net Total of Profit & Loss: $38382578
# Average Total Profit & Loss: -2315.12
# Greatest Increase in Profits: Feb-2012 $1926159
# Greatest Decrease in Profits: Sept-2013 $-2196167
